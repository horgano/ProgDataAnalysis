# %% [markdown]
# # Correlation

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # # Data Creation
# Create random data for the x and y axes. Have the y data be a straight line function of the x data with some noise added

# %%
rng = np.random.default_rng()
x = rng.random(10) * 10

# %%
y = 3*x + 4 # + (rng.random(10*2))           #Equation of a line plus noise

# %% [markdown]
# # Data Visualisation

# %%
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = 3*x + 4  + (rng.random(10)*2))
# Out:
#   Cell In[5], line 1
#     y = 3*x + 4  + (rng.random(10)*2))
#                                      ^
# SyntaxError: unmatched ')'

# %%
plt.scatter(x,y)
plt.show

# %% [markdown]
# # Correlation  - Pearsons

# %%
r = np.corrcoef(x,y)    # 1,1 is strongest correlation
r

# %% [markdown]
# Note that the data does not have to be linear to observe a correlation
# Take the below simple example of a hypothetical relationship between energy and share prices

# %%
time = np.linspace(0, 10)
energyPrice = np.sin(time)
sharePrice = (np.sin(time))*3 
plt.plot(time, energyPrice, 'r')
plt.plot(time, sharePrice, 'b')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
r = np.corrcoef(energyPrice, sharePrice)
r

# %%
time = np.linspace(0, 10)
energyPrice = np.sin(time)
sharePrice = ((np.sin(time))*3)+ ((rng.random(50)*2) -1)
plt.plot(time, energyPrice, 'r')
plt.plot(time, sharePrice, 'b')
plt.show()

# %%
r = np.corrcoef(energyPrice, sharePrice)
r
# Out:
# array([[1.        , 0.95392806],
#        [0.95392806, 1.        ]])

# %% [markdown]
# # Correlation and the Irsis Data Set

# %%
df = pd.read_csv("https://raw.githubusercontent.com/illinois-cse/data-fa14/gh-pages/data/iris.csv")
import seaborn as sns
sns.pairplot(df, hue="species")
# Out:
# C:\Users\Niall\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
r = np.corrcoef(df['sepal_width'], df['sepal_length'])
r
# Out:
# array([[ 1.        , -0.10936925],
#        [-0.10936925,  1.        ]])

# %% [markdown]
# Separate the 3 species into 3 separate dataframes

# %%
setosaDf = df.loc[df.loc[:, 'species']=='setosa']
versiDf = df.loc[df.loc[:, 'species']=='versicolor']
virgiDf = df.loc[df.loc[:, 'species']=='virginica']

# %% [markdown]
# Look at the correlations within the 3 dataframes separately

# %%
r = np.corrcoef(setosaDf['sepal_width'], setosaDf['sepal_length'])
r
# Out:
# array([[1.        , 0.74678037],
#        [0.74678037, 1.        ]])

# %%
r = np.corrcoef(versiDf['sepal_width'], versiDf['sepal_length'])
r
# Out:
# array([[1.        , 0.52591072],
#        [0.52591072, 1.        ]])

# %%
r = np.corrcoef(virgiDf['sepal_width'], virgiDf['sepal_length'])
r
# Out:
# array([[1.        , 0.45722782],
#        [0.45722782, 1.        ]])
